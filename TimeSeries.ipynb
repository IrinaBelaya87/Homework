# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm
import statsmodels.tsa.api as smt
from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt
from scipy.stats import boxcox
# %matplotlib inline

# %%
def test_stationarity(timeseries):
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
    for [key, value] in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

# %%
def tsplot(y, lags=None, figsize=(14, 8), style='bmh'):
    test_stationarity(y)
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
    with plt.style.context(style):
        plt.figure(figsize=figsize)
        layout = (4, 1)
        ts_ax = plt.subplot2grid(layout, (0, 0), rowspan=2)
        acf_ax = plt.subplot2grid(layout, (2, 0))
        pacf_ax = plt.subplot2grid(layout, (3, 0))

        y.plot(ax=ts_ax, color='blue', label='Or')
        ts_ax.set_title('Original')

        smt.graphics.plot_acf(y, lags=lags, ax=acf_ax, alpha=0.05)
        smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax, alpha=0.05)

        plt.tight_layout()
    return

# %%
series = pd.read_csv('monthly-us-auto-registration-tho.csv', sep = ';')['Monthly U.S. auto registration (thousands) 1947 ? 1968']

# %%
tsplot(series)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.225039
# p-value                          0.662733
# #Lags Used                      15.000000
# Number of Observations Used    248.000000
# Critical Value (1%)             -3.456996
# Critical Value (5%)             -2.873266
# Critical Value (10%)            -2.573019
# dtype: float64
# C:\Users\ibelaya\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1283: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %% [markdown]
# Как мы видим, и тест Дики-Фуллера и графики коррелограмм не отвергают гипотезу о нестационарности ряда. Для начала уберем изменение дисперсии при помощи преобразования Бокса-Кокса

# %%
series = boxcox(series, 0)

# %%
tsplot(series)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.941628
# p-value                          0.312738
# #Lags Used                      14.000000
# Number of Observations Used    249.000000
# Critical Value (1%)             -3.456888
# Critical Value (5%)             -2.873219
# Critical Value (10%)            -2.572994
# dtype: float64
# C:\Users\ibelaya\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1283: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %% [markdown]
# Нам удалось убрать размах дисперсии, но тест Дикки-Фуллера все еще не отвергает гипотезу о нестационарности ряда. По графику ряда видно наличие сильного тренда. Уберем его дифференцированием.

# %%
series = series[1:] - series[:-1]

# %%
tsplot(series)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -4.362471
# p-value                          0.000346
# #Lags Used                      14.000000
# Number of Observations Used    248.000000
# Critical Value (1%)             -3.456996
# Critical Value (5%)             -2.873266
# Critical Value (10%)            -2.573019
# dtype: float64
# C:\Users\ibelaya\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1283: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %% [markdown]
# Тест Дикки-Фуллера отвергает гипотезу о нестационарности ряда, но мне кажется, по графику коррелограммы видно, что есть влияние сезонности. Попробуем убрать ее

# %%
series = series[12:] - series[:-12]

# %%
tsplot(series)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.528275e+00
# p-value                        1.001817e-08
# #Lags Used                     1.200000e+01
# Number of Observations Used    2.380000e+02
# Critical Value (1%)           -3.458128e+00
# Critical Value (5%)           -2.873762e+00
# Critical Value (10%)          -2.573283e+00
# dtype: float64
# C:\Users\ibelaya\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1283: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %% [markdown]
# Проделаем тоже самое на других данных

# %%
series1 = pd.read_csv('monthly-us-auto-registration-tho.csv', sep = ';')['Monthly U.S. auto registration (thousands) 1947 ? 1968']

# %%
tsplot(series1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.225039
# p-value                          0.662733
# #Lags Used                      15.000000
# Number of Observations Used    248.000000
# Critical Value (1%)             -3.456996
# Critical Value (5%)             -2.873266
# Critical Value (10%)            -2.573019
# dtype: float64
# C:\Users\ibelaya\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1283: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %% [markdown]
# Как мы видим, и тест Дики-Фуллера и графики коррелограмм не отвергают гипотезу о нестационарности ряда. Для начала уберем изменение дисперсии при помощи преобразования Бокса-Кокса

# %%
series1 = boxcox(series1, 0)

# %%
tsplot(series1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.941628
# p-value                          0.312738
# #Lags Used                      14.000000
# Number of Observations Used    249.000000
# Critical Value (1%)             -3.456888
# Critical Value (5%)             -2.873219
# Critical Value (10%)            -2.572994
# dtype: float64
# C:\Users\ibelaya\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1283: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %% [markdown]
# Дифференцируем

# %%
series1 = np.diff(series1, 1)

# %%
tsplot(series1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -4.362471
# p-value                          0.000346
# #Lags Used                      14.000000
# Number of Observations Used    248.000000
# Critical Value (1%)             -3.456996
# Critical Value (5%)             -2.873266
# Critical Value (10%)            -2.573019
# dtype: float64
# C:\Users\ibelaya\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1283: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %% [markdown]
# Убираем сезонность

# %%
series1 = series1[12:] - series1[:-12]

# %%
tsplot(series1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.528275e+00
# p-value                        1.001817e-08
# #Lags Used                     1.200000e+01
# Number of Observations Used    2.380000e+02
# Critical Value (1%)           -3.458128e+00
# Critical Value (5%)           -2.873762e+00
# Critical Value (10%)          -2.573283e+00
# dtype: float64
# C:\Users\ibelaya\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1283: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)
